# %% [markdown]
# # Movie Recommendation System
# Create a title recommendation system based on cast, director, and title genre
# Reference: https://www.datacamp.com/community/tutorials/recommender-systems-python

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
original_df = pd.read_csv('netflix_ratings_data.csv',sep = ',')
original_df = original_df.dropna(subset=['director','cast'])

# %%
working_df = original_df.copy()
working_df = working_df.drop(columns=['rating', 'duration','year','originalTitle','averageRating', 'numVotes'])

# %%
working_df = working_df.dropna(subset=['director','cast'])

# %%
#Split columns
working_df['director'] = working_df['director'].str.split(',') 
working_df['cast'] = working_df['cast'].str.split(',') 
working_df['genres'] = working_df['genres'].str.split(',')

# %%
def clean_data(x):
    return [str.lower(i.replace(" ", "")) for i in x]

working_df['director'] = working_df['director'].apply(clean_data)
working_df['cast'] = working_df['cast'].apply(clean_data)
working_df['genres'] = working_df['genres'].apply(clean_data)

# %%
def create_soup(x):
    return ' '.join(x['cast']) + ' ' + ' '.join(x['director']) + ' ' + ' '.join(x['genres'])

# %%
working_df['soup'] = working_df.apply(create_soup, axis=1)

# %%
working_df[['title','director','cast','genres']]
# Out:
#                                  title                      director  \
# 1                            ganglands              [julienleclercq]
# 3                        midnight mass                [mikeflanagan]
# 4     my little pony: a new generation  [robertcullen, joséluisucha]
# 5                              sankofa                 [hailegerima]
# 6                         the starling               [theodoremelfi]
# ...                                ...                           ...
# 6414                             zenda               [avadhootgupte]
# 6416                            zodiac                [davidfincher]
# 6417                        zombieland              [rubenfleischer]
# 6418                              zoom                 [peterhewitt]
# 6419                            zubaan                  [mozezsingh]
#
#                                                    cast  \
# 1     [samibouajila, tracygotoas, samueljouy, nabiha...
# 3     [katesiegel, zachgilford, hamishlinklater, hen...
# 4     [vanessahudgens, kimikoglenn, jamesmarsden, so...
# 5     [kofighanaba, oyafunmikeogunlano, alexandradua...
# 6     [melissamccarthy, chriso'dowd, kevinkline, tim...
# ...                                                 ...
# 6414  [santoshjuvekar, siddharthchandekar, sachitpat...
# 6416  [markruffalo, jakegyllenhaal, robertdowneyjr.,...
# 6417  [jesseeisenberg, woodyharrelson, emmastone, ab...
# 6418  [timallen, courteneycox, chevychase, katemara,...
# 6419  [vickykaushal, sarah-janedias, raaghavchanana,...
#
#                               genres
# 1             [action, crime, drama]
# 3           [drama, fantasy, horror]
# 4     [adventure, animation, comedy]
# 5                            [drama]
# 6                    [comedy, drama]
# ...                              ...
# 6414               [drama, thriller]
# 6416         [crime, drama, mystery]
# 6417        [action, comedy, horror]
# 6418     [action, adventure, comedy]
# 6419                         [drama]
#
# [4690 rows x 4 columns]

# %%
working_df[['soup']]
# Out:
#                                                    soup
# 1     samibouajila tracygotoas samueljouy nabihaakka...
# 3     katesiegel zachgilford hamishlinklater henryth...
# 4     vanessahudgens kimikoglenn jamesmarsden sofiac...
# 5     kofighanaba oyafunmikeogunlano alexandraduah n...
# 6     melissamccarthy chriso'dowd kevinkline timothy...
# ...                                                 ...
# 6414  santoshjuvekar siddharthchandekar sachitpatil ...
# 6416  markruffalo jakegyllenhaal robertdowneyjr. ant...
# 6417  jesseeisenberg woodyharrelson emmastone abigai...
# 6418  timallen courteneycox chevychase katemara ryan...
# 6419  vickykaushal sarah-janedias raaghavchanana man...
#
# [4690 rows x 1 columns]

# %%
count = CountVectorizer(stop_words='english')
count_matrix = count.fit_transform(working_df['soup'])

# %%
cosine_sim2 = cosine_similarity(count_matrix, count_matrix)

# %%
working_df = working_df.reset_index()
indices = pd.Series(working_df.index, index=working_df['title'])

# %% [markdown]
# # Write function to return the recommendation list

# %%
def get_recommendations(title, cosine_sim):
    # Get the index of the movie that matches the title
    idx = indices[title]

    # Get the pairwsie similarity scores of all movies with that movie
    sim_scores = list(enumerate(cosine_sim[idx]))

    # Sort the movies based on the similarity scores
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)

    # Get the scores of the 10 most similar movies
    sim_scores = sim_scores[1:11]

    # Get the movie indices
    movie_indices = [i[0] for i in sim_scores]

    # Return the top 10 most similar movies
    return original_df.iloc[movie_indices]

# %%
original_df[original_df['title']=='before i wake']
# Out:
#      show_id   type          title       director  \
# 3638   s5092  Movie  before i wake  Mike Flanagan
#
#                                                    cast rating duration  \
# 3638  Kate Bosworth, Thomas Jane, Jacob Tremblay, An...  PG-13   97 min
#
#       originalTitle  year                genres  averageRating  numVotes  \
# 3638  Before I Wake  2016  Drama,Fantasy,Horror            6.2     45365
#
#        ranking
# 3638  Positive

# %%
get_recommendations('before i wake', cosine_sim2)
# Out:
#      show_id     type                                             title  \
# 3         s6  TV Show                                     midnight mass
# 254     s354    Movie  the haunting in connecticut 2: ghosts of georgia
# 165     s230    Movie                                      the old ways
# 3354   s4686  TV Show                                             ghoul
# 2672   s3758    Movie                                     the 3rd eye 2
# 3754   s5253    Movie                                     gerald's game
# 1941   s2750    Movie                                          wildling
# 3450   s4806    Movie                                          the maus
# 4711   s6524    Movie                                        compulsion
# 5275   s7303    Movie                                       lifechanger
#
#                  director                                               cast  \
# 3           Mike Flanagan  Kate Siegel, Zach Gilford, Hamish Linklater, H...
# 254            Tom Elkins  Abigail Spencer, Chad Michael Murray, Katee Sa...
# 165   Christopher Alender  Brigitte Kali Canales, Andrea Cortes, Julia Ve...
# 3354       Patrick Graham  Radhika Apte, Manav Kaul, Ratnabali Bhattachar...
# 2672         Rocky Soraya  Jessica Mila, Bianca Hello, Nabilah Ayu, Sophi...
# 3754        Mike Flanagan  Carla Gugino, Bruce Greenwood, Henry Thomas, C...
# 1941           Fritz Böhm  Bel Powley, Brad Dourif, Liv Tyler, Collin Kel...
# 3450         Yayo Herrero  Alma Terzic, August Wittgenstein, Aleksandar S...
# 4711       Craig Goodwill  Analeigh Tipton, Jakob Cedergren, Marta Gastin...
# 5275     Justin McConnell  Lora Burke, Jack Foley, Bill Oberst Jr., Elits...
#
#      rating  duration                                     originalTitle  year  \
# 3     TV-MA  1 Season                                     Midnight Mass  2021
# 254       R   101 min  The Haunting in Connecticut 2: Ghosts of Georgia  2013
# 165   TV-MA    90 min                                      The Old Ways  2020
# 3354  TV-MA  1 Season                                             Ghoul  2018
# 2672  TV-MA   117 min                                      Mata Batin 2  2019
# 3754  TV-MA   103 min                                     Gerald's Game  2017
# 1941      R    93 min                                          Wildling  2018
# 3450  TV-MA    90 min                                          The Maus  2017
# 4711  TV-MA    84 min                                             Sadie  2016
# 5275  TV-MA    84 min                                       Lifechanger  2018
#
#                      genres  averageRating  numVotes   ranking
# 3      Drama,Fantasy,Horror            7.7    100194  Positive
# 254    Drama,Horror,Mystery            5.3     17158    Medium
# 165    Drama,Fantasy,Horror            5.4      5603    Medium
# 3354   Drama,Fantasy,Horror            7.1     13711  Positive
# 2672   Drama,Fantasy,Horror            5.4       583    Medium
# 3754  Drama,Horror,Thriller            6.5    104267  Positive
# 1941   Drama,Fantasy,Horror            5.5     13722    Medium
# 3450   Drama,Fantasy,Horror            4.7      6344    Medium
# 4711   Drama,Fantasy,Horror            3.7      1499  Negative
# 5275   Drama,Fantasy,Horror            5.4      2419    Medium
